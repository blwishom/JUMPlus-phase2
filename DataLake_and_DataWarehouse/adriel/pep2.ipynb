# %%
#Calling Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataLake = pd.read_csv('data_lake.csv')
# Out:
# C:\Users\bwelp\AppData\Local\Temp\ipykernel_18060\3600154685.py:1: DtypeWarning: Columns (3,4,6,7,8,9,10,11,15,16,17,18,21,22,24,25,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataLake = pd.read_csv('data_lake.csv')

# %% [markdown]
# #### Uncleaned csv file

# %%
dataLake.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0     item_id                   name
# 0              0         0.0  90420332.0               FREKVENS  \
# 1              1         1.0    368814.0              NORDVIKEN
# 2              2         2.0   9333523.0  NORDVIKEN / NORDVIKEN
# 3              3         3.0  80155205.0                   STIG
# 4              4         4.0  30180504.0                NORBERG
# 5              5         5.0  10122647.0                 INGOLF
# 6              6         6.0  70404875.0               FRANKLIN
# 7              7         7.0  60155602.0                DALFRED
# 8              8         8.0  50406465.0               FRANKLIN
# 9              9         9.0  69304221.0    EKEDALEN / EKEDALEN
# 10            10        10.0  90404879.0               FRANKLIN
# 11            11        11.0    121766.0                 INGOLF
# 12            12        12.0    397736.0               NORRARYD
# 13            13        13.0  50420329.0               FREKVENS
# 14            14        14.0    400550.0               EKEDALEN
# 15            15        15.0  29304826.0               TOMMARYD
# 16            16        16.0  40426138.0             HENRIKSDAL
# 17            17        17.0  50363649.0              KULLABERG
# 18            18        18.0  70246089.0                JANINGE
# 19            19        19.0  60406785.0               FRANKLIN
#
#          category   price     old_price sellable_online
# 0   Bar furniture   265.0  No old price            True  \
# 1   Bar furniture   995.0  No old price           False
# 2   Bar furniture  2095.0  No old price           False
# 3   Bar furniture    69.0  No old price            True
# 4   Bar furniture   225.0  No old price            True
# 5   Bar furniture   345.0  No old price            True
# 6   Bar furniture   129.0  No old price            True
# 7   Bar furniture   195.0  No old price            True
# 8   Bar furniture   129.0  No old price            True
# 9   Bar furniture  2176.0      SR 2,375            True
# 10  Bar furniture   149.0  No old price            True
# 11  Bar furniture   395.0  No old price            True
# 12  Bar furniture   395.0  No old price            True
# 13  Bar furniture   177.0        SR 295            True
# 14  Bar furniture   345.0  No old price            True
# 15  Bar furniture   695.0  No old price            True
# 16  Bar furniture   395.0  No old price            True
# 17  Bar furniture   140.0        SR 175            True
# 18  Bar furniture   595.0  No old price            True
# 19  Bar furniture   149.0  No old price            True
#
#                                                  link other_colors  ...
# 0   https://www.ikea.com/sa/en/p/frekvens-bar-tabl...           No  ...  \
# 1   https://www.ikea.com/sa/en/p/nordviken-bar-tab...           No  ...
# 2   https://www.ikea.com/sa/en/p/nordviken-nordvik...           No  ...
# 3   https://www.ikea.com/sa/en/p/stig-bar-stool-wi...          Yes  ...
# 4   https://www.ikea.com/sa/en/p/norberg-wall-moun...           No  ...
# 5   https://www.ikea.com/sa/en/p/ingolf-bar-stool-...           No  ...
# 6   https://www.ikea.com/sa/en/p/franklin-bar-stoo...           No  ...
# 7   https://www.ikea.com/sa/en/p/dalfred-bar-stool...           No  ...
# 8   https://www.ikea.com/sa/en/p/franklin-bar-stoo...           No  ...
# 9   https://www.ikea.com/sa/en/p/ekedalen-ekedalen...           No  ...
# 10  https://www.ikea.com/sa/en/p/franklin-bar-stoo...           No  ...
# 11  https://www.ikea.com/sa/en/p/ingolf-bar-stool-...           No  ...
# 12  https://www.ikea.com/sa/en/p/norraryd-bar-stoo...           No  ...
# 13  https://www.ikea.com/sa/en/p/frekvens-bar-stoo...           No  ...
# 14  https://www.ikea.com/sa/en/p/ekedalen-bar-stoo...           No  ...
# 15  https://www.ikea.com/sa/en/p/tommaryd-table-an...           No  ...
# 16  https://www.ikea.com/sa/en/p/henriksdal-bar-st...           No  ...
# 17  https://www.ikea.com/sa/en/p/kullaberg-stool-b...          Yes  ...
# 18  https://www.ikea.com/sa/en/p/janinge-bar-stool...           No  ...
# 19  https://www.ikea.com/sa/en/p/franklin-bar-stoo...           No  ...
#
#    no_of_reviews ratings  author  cover_type  year genre date product market
# 0            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN  \
# 1            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 2            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 3            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 4            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 5            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 6            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 7            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 8            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 9            NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 10           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 11           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 12           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 13           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 14           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 15           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 16           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 17           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 18           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
# 19           NaN     NaN     NaN         NaN   NaN   NaN  NaN     NaN    NaN
#
#     size
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
#
# [20 rows x 32 columns]

# %% [markdown]
# #### Separating the IKEA records

# %%
ikea = dataLake[['Unnamed: 0.1','item_id','name','category','price','link','designer','depth','height','width','short_description',]]
ikea = ikea[ikea['item_id'].notna()].replace(np.nan,1).rename(columns={"Unnamed: 0.1": "record_number","name": "product_name","item_id": "item_number"}).set_index('record_number').sort_values('record_number')
ikea['item_number'] = ikea['item_number'].astype(str).apply(lambda x: x.replace('.0','')).astype(int)
ikea[['product_name','category','link','designer','short_description']] = ikea[['product_name','category','link','designer','short_description']].astype(str)
ikea[['price','depth','height','width']] = ikea[['price','depth','height','width']].astype(int)
ikea.head(20)
# Out:
#                item_number           product_name       category  price
# record_number
# 0                 90420332               FREKVENS  Bar furniture    265  \
# 1                   368814              NORDVIKEN  Bar furniture    995
# 2                  9333523  NORDVIKEN / NORDVIKEN  Bar furniture   2095
# 3                 80155205                   STIG  Bar furniture     69
# 4                 30180504                NORBERG  Bar furniture    225
# 5                 10122647                 INGOLF  Bar furniture    345
# 6                 70404875               FRANKLIN  Bar furniture    129
# 7                 60155602                DALFRED  Bar furniture    195
# 8                 50406465               FRANKLIN  Bar furniture    129
# 9                 69304221    EKEDALEN / EKEDALEN  Bar furniture   2176
# 10                90404879               FRANKLIN  Bar furniture    149
# 11                  121766                 INGOLF  Bar furniture    395
# 12                  397736               NORRARYD  Bar furniture    395
# 13                50420329               FREKVENS  Bar furniture    177
# 14                  400550               EKEDALEN  Bar furniture    345
# 15                29304826               TOMMARYD  Bar furniture    695
# 16                40426138             HENRIKSDAL  Bar furniture    395
# 17                50363649              KULLABERG  Bar furniture    140
# 18                70246089                JANINGE  Bar furniture    595
# 19                60406785               FRANKLIN  Bar furniture    149
#
#                                                             link
# record_number
# 0              https://www.ikea.com/sa/en/p/frekvens-bar-tabl...  \
# 1              https://www.ikea.com/sa/en/p/nordviken-bar-tab...
# 2              https://www.ikea.com/sa/en/p/nordviken-nordvik...
# 3              https://www.ikea.com/sa/en/p/stig-bar-stool-wi...
# 4              https://www.ikea.com/sa/en/p/norberg-wall-moun...
# 5              https://www.ikea.com/sa/en/p/ingolf-bar-stool-...
# 6              https://www.ikea.com/sa/en/p/franklin-bar-stoo...
# 7              https://www.ikea.com/sa/en/p/dalfred-bar-stool...
# 8              https://www.ikea.com/sa/en/p/franklin-bar-stoo...
# 9              https://www.ikea.com/sa/en/p/ekedalen-ekedalen...
# 10             https://www.ikea.com/sa/en/p/franklin-bar-stoo...
# 11             https://www.ikea.com/sa/en/p/ingolf-bar-stool-...
# 12             https://www.ikea.com/sa/en/p/norraryd-bar-stoo...
# 13             https://www.ikea.com/sa/en/p/frekvens-bar-stoo...
# 14             https://www.ikea.com/sa/en/p/ekedalen-bar-stoo...
# 15             https://www.ikea.com/sa/en/p/tommaryd-table-an...
# 16             https://www.ikea.com/sa/en/p/henriksdal-bar-st...
# 17             https://www.ikea.com/sa/en/p/kullaberg-stool-b...
# 18             https://www.ikea.com/sa/en/p/janinge-bar-stool...
# 19             https://www.ikea.com/sa/en/p/franklin-bar-stoo...
#
#                                       designer  depth  height  width
# record_number
# 0                         Nicholai Wiig Hansen      1      99     51  \
# 1                            Francis Cayouette      1     105     80
# 2                            Francis Cayouette      1       1      1
# 3                                Henrik Preutz     50     100     60
# 4                               Marcus Arvonen     60      43     74
# 5                                 Carina Bengs     45      91     40
# 6                          K Hagberg/M Hagberg     44      95     50
# 7                                  Sarah Fager     50       1     50
# 8                          K Hagberg/M Hagberg     44      95     50
# 9                              Ehlén Johansson      1       1      1
# 10                         K Hagberg/M Hagberg     44     103     52
# 11                                Carina Bengs     45     102     40
# 12                               Nike Karlsson     47     103     46
# 13                        Nicholai Wiig Hansen     53     104     43
# 14                             Ehlén Johansson     52     114     43
# 15                             Maja Ganszyniec      1     105     70
# 16                               Karl Malmvall     51     102     40
# 17                                 Sarah Fager     36       1     36
# 18             John/Jonas/Petrus/Paul/Caroline     36      84     38
# 19                         K Hagberg/M Hagberg     44     103     52
#
#                                                short_description
# record_number
# 0                       Bar table, in/outdoor,          51x51 cm
# 1                                  Bar table,          140x80 cm
# 2                                     Bar table and 4 bar stools
# 3                        Bar stool with backrest,          74 cm
# 4                      Wall-mounted drop-leaf table,         ...
# 5                        Bar stool with backrest,          63 cm
# 6                      Bar stool with backrest, foldable,    ...
# 7                                   Bar stool,          63-74 cm
# 8                      Bar stool with backrest, foldable,    ...
# 9                                     Bar table and 4 bar stools
# 10                     Bar stool with backrest, foldable,    ...
# 11                       Bar stool with backrest,          74 cm
# 12                       Bar stool with backrest,          74 cm
# 13                     Bar stool with backrest, in/outdoor,  ...
# 14                       Bar stool with backrest,          75 cm
# 15                                 Table,          130x70/105 cm
# 16                     Bar stool with backrest frame,        ...
# 17                                                         Stool
# 18                                     Bar stool,          76 cm
# 19                     Bar stool with backrest, foldable,    ...

# %%
print('Number of unique Designers: ',ikea['designer'].nunique())
# Out:
# Number of unique Designers:  381

# %%
print('Most expensive product(s): ')
high_furn = ikea[ikea['price'] == ikea['price'].max()]
high_furn
# Out:
# Most expensive product(s):
#                item_number product_name           category  price
# record_number
# 190               29277639      LIDHULT               Beds   9585  \
# 2344              79277632      LIDHULT  Sofas & armchairs   9585
#
#                                                             link
# record_number
# 190            https://www.ikea.com/sa/en/p/lidhult-corner-so...  \
# 2344           https://www.ikea.com/sa/en/p/lidhult-corner-so...
#
#                                    designer  depth  height  width
# record_number
# 190            Henrik Preutz/IKEA of Sweden    164     102    387  \
# 2344           Henrik Preutz/IKEA of Sweden    164     102    387
#
#                              short_description
# record_number
# 190                    Corner sofa-bed, 6-seat
# 2344                   Corner sofa-bed, 6-seat

# %%
print('Cheapest product(s): ')
low_furn = ikea[ikea['price'] == ikea['price'].min()]
low_furn
# Out:
# Cheapest product(s):
#                item_number product_name                    category  price
# record_number
# 389               80336433      GUBBARP  Bookcases & shelving units      3  \
# 879               80336433      GUBBARP        Cabinets & cupboards      3
# 3349              80336433      GUBBARP        TV & media furniture      3
#
#                                                             link
# record_number
# 389            https://www.ikea.com/sa/en/p/gubbarp-knob-whit...  \
# 879            https://www.ikea.com/sa/en/p/gubbarp-knob-whit...
# 3349           https://www.ikea.com/sa/en/p/gubbarp-knob-whit...
#
#                              designer  depth  height  width
# record_number
# 389            H Preutz/A Fredriksson     27       1      1  \
# 879            H Preutz/A Fredriksson     27       1      1
# 3349           H Preutz/A Fredriksson     27       1      1
#
#                           short_description
# record_number
# 389                    Knob,          21 mm
# 879                    Knob,          21 mm
# 3349                   Knob,          21 mm

# %% [markdown]
# #### Separating Store records

# %%
store = dataLake[['Unnamed: 0.1','date','product','market','size']]
store = store[store['date'].notna()].rename(columns={"Unnamed: 0.1": "sale_number",}).replace(np.nan,0).set_index('sale_number')
store['date'] = pd.to_datetime(store.date)
store[['product','market','size']] = store[['product','market','size']].astype(str)
store.head(15)
# Out:
#                   date                         product             market size
# sale_number
# 0           2019-01-02         Aleika High Grade Flour               Bars   kg
# 1           2019-01-02         Aleika High Grade Flour         Bayanzurkh   kg
# 2           2019-01-02         Aleika High Grade Flour           Bumbugur   kg
# 3           2019-01-02         Aleika High Grade Flour              Emart   kg
# 4           2019-01-02         Aleika High Grade Flour         Kharkhorin   kg
# 5           2019-01-02         Aleika High Grade Flour   Khuchit Shonkhor   kg
# 6           2019-01-02         Aleika High Grade Flour         Max/M Mart   kg
# 7           2019-01-02         Aleika High Grade Flour  Mercury/Ikh Nayad   kg
# 8           2019-01-02         Aleika High Grade Flour              Nomin   kg
# 9           2019-01-02         Aleika High Grade Flour              Orgil   kg
# 10          2019-01-02         Aleika High Grade Flour             Sansar   kg
# 11          2019-01-02         Aleika High Grade Flour             Saruul   kg
# 12          2019-01-02         Aleika High Grade Flour       Tavan Erdene   kg
# 13          2019-01-02  Altan Taria Flour, First Grade               Bars   kg
# 14          2019-01-02  Altan Taria Flour, First Grade         Bayanzurkh   kg

# %% [markdown]
# #### Separating Pokemon Card Records

# %%
pokemon = dataLake[['Unnamed: 0.1','Pokemon','Card Type','Generation','Card Number','Price']]
pokemon = pokemon[pokemon['Pokemon'].notna()] \
    .rename(columns={"Unnamed: 0.1": "item_number","Pokemon": "pokemon_name","Card Type": "card_type","Card Number": "card_number","Generation": "generation","Price": "price"}).set_index('item_number')
pokemon[['pokemon_name','card_type','generation','card_number']] = pokemon[['pokemon_name','card_type','generation','card_number']].astype(str)
pokemon.head(20)
# Out:
#             pokemon_name     card_type generation card_number  price
# item_number
# 0               AMPHAROS  REVERSE HOLO  AQUAPOLIS  001 OF 147   2.95
# 1               AMPHAROS      STANDARD  AQUAPOLIS  001 OF 147   2.50
# 2               ARCANINE  REVERSE HOLO  AQUAPOLIS  002 OF 147   3.95
# 3               ARCANINE      STANDARD  AQUAPOLIS  002 OF 147   2.95
# 4                ARIADOS  REVERSE HOLO  AQUAPOLIS  003 OF 147   2.50
# 5                ARIADOS      STANDARD  AQUAPOLIS  003 OF 147   1.50
# 6              AZUMARILL  REVERSE HOLO  AQUAPOLIS  004 OF 147   2.95
# 7              AZUMARILL      STANDARD  AQUAPOLIS  004 OF 147   1.95
# 8              BELLOSSOM  REVERSE HOLO  AQUAPOLIS  005 OF 147   2.95
# 9              BELLOSSOM      STANDARD  AQUAPOLIS  005 OF 147   1.95
# 10               BLISSEY  REVERSE HOLO  AQUAPOLIS  006 OF 147   2.95
# 11               BLISSEY      STANDARD  AQUAPOLIS  006 OF 147   1.95
# 12               DONPHAN  REVERSE HOLO  AQUAPOLIS  007 OF 147   3.95
# 13               DONPHAN      STANDARD  AQUAPOLIS  007 OF 147   2.95
# 14             ELECTRODE  REVERSE HOLO  AQUAPOLIS  008 OF 147   2.50
# 15             ELECTRODE      STANDARD  AQUAPOLIS  008 OF 147   1.50
# 16                ELEKID  REVERSE HOLO  AQUAPOLIS  009 OF 147   3.50
# 17                ELEKID      STANDARD  AQUAPOLIS  009 OF 147   2.50
# 18                 ENTEI  REVERSE HOLO  AQUAPOLIS  010 OF 147   4.95
# 19                 ENTEI      STANDARD  AQUAPOLIS  010 OF 147   3.95

# %%
print("Most expensive card of each Generation")
high_gen = pokemon.groupby('generation')['price'].max()
print(high_gen)

print()

print("Cheapest card of each Generation")
low_gen = pokemon.groupby('generation')['price'].min()
print(low_gen)
# Out:
# Most expensive card of each Generation
# generation
# AQUAPOLIS                   119.99
# ARCEUS                       11.95
# B&W - BOUNDARIES CROSSED     48.99
# B&W - DARK EXPLORERS         43.99
# B&W - DRAGONS EXALTED        33.99
#                              ...
# XY - PHANTOM FORCES          38.99
# XY - PRIMAL CLASH            13.99
# XY - ROARING SKIES           17.99
# XY - SHINING LEGENDS         33.99
# XY - STEAM SIEGE             13.99
# Name: price, Length: 217, dtype: float64
#
# Cheapest card of each Generation
# generation
# AQUAPOLIS                   0.20
# ARCEUS                      0.10
# B&W - BOUNDARIES CROSSED    0.29
# B&W - DARK EXPLORERS        0.09
# B&W - DRAGONS EXALTED       0.19
#                             ...
# XY - PHANTOM FORCES         0.09
# XY - PRIMAL CLASH           0.09
# XY - ROARING SKIES          0.09
# XY - SHINING LEGENDS        0.09
# XY - STEAM SIEGE            0.09
# Name: price, Length: 217, dtype: float64

# %% [markdown]
# #### Separating Book Records

# %%
books = dataLake[['Unnamed: 0.1','ranks','title','no_of_reviews','ratings','author','cover_type','year','genre']]
books = books[books['ranks'].notna()].rename(columns={"Unnamed: 0.1": "book_id"}).set_index('book_id')
books['ranks'] = books['ranks'].astype(str).apply(lambda x: x.replace('.0','')).astype(int)
books['year'] = books['year'].astype(str).apply(lambda x: x.replace('.0','')).astype(int)
books['no_of_reviews'] = books['no_of_reviews'].astype(str).apply(lambda x: x.replace(',','')).astype(int)
books['ratings'].astype(int)
books['genre'] = books['genre'].replace('unknown','Other')
books.tail(10)
# Out:
#          ranks                                              title
# book_id
# 1281        91  The Step-by-Step Instant Pot Cookbook: 100 Sim...  \
# 1282        92                        The Vanishing Half: A Novel
# 1283        93                                    A Promised Land
# 1284        94  What Should Danny Do? (The Power to Choose Ser...
# 1285        95                                           The Wish
# 1286        96                                               Will
# 1287        97  Think and Grow Rich: The Landmark Bestseller N...
# 1288        98                                 Dragons Love Tacos
# 1289        99  The Truth About COVID-19: Exposing The Great R...
# 1290       100  First Little Readers Parent Pack: Guided Readi...
#
#          no_of_reviews  ratings                 author cover_type  year
# book_id
# 1281             30581      4.7         Jeffrey Eisner  Paperback  2021  \
# 1282             96412      4.4           Brit Bennett  Hardcover  2021
# 1283            125017      4.9           Barack Obama  Hardcover  2021
# 1284             22169      4.8              Adir Levy  Hardcover  2021
# 1285             35292      4.7        Nicholas Sparks  Hardcover  2021
# 1286             21401      4.8             Will Smith  Hardcover  2021
# 1287             79872      4.7          Napoleon Hill  Paperback  2021
# 1288             15753      4.8             Adam Rubin  Hardcover  2021
# 1289              7246      4.8  Doctor Joseph Mercola  Hardcover  2021
# 1290             27332      4.7       Deborah Schecter  Paperback  2021
#
#                genre
# book_id
# 1281     Non Fiction
# 1282         Fiction
# 1283     Non Fiction
# 1284         Fiction
# 1285         Fiction
# 1286     Non Fiction
# 1287     Non Fiction
# 1288         Fiction
# 1289     Non Fiction
# 1290     Non Fiction

# %%
corr_review_rate = books['no_of_reviews'].corr(books['ratings'])
print("The correlation between the number of reviews and ratings is: ",corr_review_rate)

corr_rank_rate = books['ranks'].corr(books['ratings'])
print("The correlation between the book ranking and ratings is: ",corr_rank_rate )
# Out:
# The correlation between the number of reviews and ratings is:  0.17327873701234026
# The correlation between the book ranking and ratings is:  -0.014559168438934464

# %%
fig = sns.lineplot(
    data=books,
    x="ratings", y="no_of_reviews", hue="genre",
)

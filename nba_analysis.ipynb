# %%
import pandas as pd
import pyspark as ps
import pyspark.sql.functions
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nba_df = pd.read_csv('/home/blair/cognixia/AdvancedPhase/DataLake_and_DataWarehouse/nba_cleaned.csv')
nba_df
# Out:
#       person_id  display_first_last            birthdate
# 0          51.0  Mahmoud Abdul-Rauf  1969-03-09 00:00:00  \
# 1        1505.0   Tariq Abdul-Wahad  1974-11-03 00:00:00
# 2      203919.0        Jordan Adams  1994-07-08 00:00:00
# 3         912.0      Rafael Addison  1964-07-22 00:00:00
# 4      201336.0        Blake Ahearn  1984-05-27 00:00:00
# ...         ...                 ...                  ...
# 1781  1627757.0   Stephen Zimmerman  1996-09-09 00:00:00
# 1782  1627835.0         Paul Zipser  1994-02-18 00:00:00
# 1783  1627790.0          Ante Zizic  1997-01-04 00:00:00
# 1784    78648.0           Bill Zopf  1948-06-07 00:00:00
# 1785  1627826.0         Ivica Zubac  1997-03-18 00:00:00
#
#                                    school  country height  weight  season_exp
# 0                         Louisiana State      USA    6-1   162.0         9.0  \
# 1                          San Jose State   France    6-6   235.0         7.0
# 2                                    UCLA      USA    6-5   209.0         3.0
# 3                                Syracuse      USA    6-8   241.0         6.0
# 4                          Missouri State      USA    6-2   190.0         4.0
# ...                                   ...      ...    ...     ...         ...
# 1781                                 UNLV      USA    7-0   240.0         2.0
# 1782                        Bayern Munich  Germany    6-8   226.0         2.0
# 1783                                       Croatia   6-10   266.0         4.0
# 1784                             Duquesne      USA    6-1   170.0         1.0
# 1785                          Mega Basket  Croatia    7-0   240.0         6.0
#
#      jersey       position rosterstatus  team_name draft_year draft_round
# 0         1          Guard     Inactive    Nuggets       1990           1  \
# 1         9  Forward-Guard     Inactive      Kings       1997           1
# 2         3          Guard     Inactive  Grizzlies       2014           1
# 3         7        Forward     Inactive       Nets       1986           2
# 4         2          Guard     Inactive       Heat  Undrafted   Undrafted
# ...     ...            ...          ...        ...        ...         ...
# 1781     33         Center     Inactive      Magic       2016           2
# 1782     16        Forward     Inactive      Bulls       2016           2
# 1783     41         Center     Inactive  Cavaliers       2016           1
# 1784      6          Guard     Inactive      Bucks       1970           2
# 1785     40         Center       Active   Clippers       2016           2
#
#      draft_number greatest_75_flag
# 0               3                N
# 1              11                N
# 2              22                N
# 3              39                N
# 4       Undrafted                N
# ...           ...              ...
# 1781           41                N
# 1782           48                N
# 1783           23                N
# 1784           33                N
# 1785           32                N
#
# [1786 rows x 16 columns]

# %%
nba_greatest_75 = nba_df.loc[nba_df['greatest_75_flag'].eq('Y')]
# nba_greatest_75.groupby(['team_name']).describe()
nba_greatest_75_by_team = nba_greatest_75['team_name']
# nba_greatest_75_by_team = pd.DataFrame(nba_greatest_75_by_team)
nba_greatest_75_by_team.describe()
# Out:
# count         36
# unique        20
# top       Lakers
# freq           8
# Name: team_name, dtype: object

# %%
sns.histplot(data=nba_greatest_75_by_team)
plt.title('NBA Top 75 Team')
plt.xlabel('Team Name')
plt.ylabel('Count of Players')
plt.xticks(rotation=90)
plt.show()

# %%
warriors = nba_df[nba_df['team_name'].isin(['Warriors'])]
drafted_warriors = warriors.loc[warriors['draft_year'].ne('Undrafted')]
most_current_warriors = drafted_warriors.loc[drafted_warriors['draft_year'].ge('2005')]

drafted_warriors
most_current_warriors
# Out:
#       person_id      display_first_last            birthdate
# 68     202357.0         Nemanja Bjelica  1988-05-09 00:00:00  \
# 541    202724.0         Charles Jenkins  1989-02-28 00:00:00
# 548   1629660.0               Ty Jerome  1997-07-08 00:00:00
# 698   1630228.0        Jonathan Kuminga  2002-10-06 00:00:00
# 779   1626172.0            Kevon Looney  1996-02-06 00:00:00
# 822   1630185.0            Nico Mannion  2001-03-14 00:00:00
# 973    203517.0         Nemanja Nedovic  1991-06-16 00:00:00
# 1053   200785.0           Kosta Perovic  1985-02-19 00:00:00
# 1178  1631157.0            Ryan Rollins  2002-07-03 00:00:00
# 1296  1629346.0          Alen Smailagic  2000-08-18 00:00:00
# 1340  1629016.0          Omari Spellman  1997-07-21 00:00:00
# 1408   101147.0              Chris Taft  1985-03-10 00:00:00
# 1455   202691.0           Klay Thompson  1990-02-08 00:00:00
# 1509   202719.0            Jeremy Tyler  1991-06-21 00:00:00
# 1602  1629683.0  Quinndary Weatherspoon  1996-09-10 00:00:00
# 1646   203952.0          Andrew Wiggins  1995-02-23 00:00:00
#
#                       school country height  weight  season_exp jersey
# 68                Fenerbahce  Serbia    6-9   234.0         8.0      8  \
# 541                  Hofstra     USA    6-3   215.0         3.0     31
# 548                 Virginia     USA    6-5   195.0         3.0     10
# 698      NBA G League Ignite     DRC    6-7   225.0         1.0     00
# 779                     UCLA     USA    6-9   222.0         7.0      5
# 822                  Arizona   Italy    6-2   190.0         2.0      2
# 973   Lietuvos rytas Vilnius  Serbia    6-3   192.0         2.0      8
# 1053                Partizan  Serbia    7-2   240.0         2.0     19
# 1178                  Toledo     USA    6-3   180.0         0.0      2
# 1296                    Beko  Serbia   6-10   215.0         3.0      6
# 1340               Villanova     USA    6-8   245.0         3.0     14
# 1408              Pittsburgh     USA   6-10   261.0         2.0     21
# 1455        Washington State     USA    6-6   220.0         9.0     11
# 1509            Tokyo Apache     USA   6-10   250.0         4.0      4
# 1602       Mississippi State     USA    6-3   205.0         4.0     15
# 1646                  Kansas  Canada    6-7   197.0         8.0     22
#
#            position rosterstatus team_name draft_year draft_round
# 68          Forward     Inactive  Warriors       2010           2  \
# 541           Guard     Inactive  Warriors       2011           2
# 548   Guard-Forward       Active  Warriors       2019           1
# 698         Forward       Active  Warriors       2021           1
# 779         Forward       Active  Warriors       2015           1
# 822           Guard     Inactive  Warriors       2020           2
# 973           Guard     Inactive  Warriors       2013           1
# 1053         Center     Inactive  Warriors       2006           2
# 1178          Guard       Active  Warriors       2022           2
# 1296        Forward     Inactive  Warriors       2019           2
# 1340        Forward     Inactive  Warriors       2018           1
# 1408        Forward     Inactive  Warriors       2005           2
# 1455          Guard       Active  Warriors       2011           1
# 1509        Forward     Inactive  Warriors       2011           2
# 1602          Guard     Inactive  Warriors       2019           2
# 1646        Forward       Active  Warriors       2014           1
#
#      draft_number greatest_75_flag
# 68             35                N
# 541            44                N
# 548            24                N
# 698             7                N
# 779            30                N
# 822            48                N
# 973            30                N
# 1053           38                N
# 1178           44                N
# 1296           39                N
# 1340           30                N
# 1408           42                N
# 1455           11                N
# 1509           39                N
# 1602           49                N
# 1646            1                N

# %%
kings = nba_df[nba_df['team_name'].isin(['Kings'])]
drafted_kings = kings.loc[kings['draft_year'].ne('Undrafted')]
most_current_kings = drafted_kings.loc[drafted_kings['draft_year'].ge('2005')]

most_current_kings
# Out:
#       person_id    display_first_last            birthdate            school
# 271   1628368.0          De'Aaron Fox  1997-12-20 00:00:00          Kentucky  \
# 362    201590.0          Donte Greene  1988-02-21 00:00:00          Syracuse
# 403    203090.0      Maurice Harkless  1993-05-11 00:00:00  St. John's, N.Y.
# 499   1628989.0         Kevin Huerter  1998-08-27 00:00:00          Maryland
# 531   1629713.0          Justin James  1997-01-24 00:00:00           Wyoming
# 686    201585.0          Kosta Koufos  1989-02-24 00:00:00        Ohio State
# 708   1627746.0       Skal Labissiere  1996-03-18 00:00:00          Kentucky
# 716    203087.0           Jeremy Lamb  1992-05-30 00:00:00       Connecticut
# 719    201171.0           Carl Landry  1983-09-19 00:00:00            Purdue
# 747    203458.0              Alex Len  1993-06-16 00:00:00          Maryland
# 797   1626168.0            Trey Lyles  1995-11-05 00:00:00          Kentucky
# 927   1630558.0       Davion Mitchell  1998-09-05 00:00:00            Baylor
# 960   1631099.0         Keegan Murray  2000-08-19 00:00:00              Iowa
# 1026  1627834.0  Georgios Papagiannis  1997-07-03 00:00:00     Panathinaikos
# 1105  1629674.0         Neemias Queta  1999-07-13 00:00:00        Utah State
# 1203  1627734.0      Domantas Sabonis  1996-05-03 00:00:00           Gonzaga
# 1453   201574.0        Jason Thompson  1986-07-21 00:00:00  Rider University
#
#         country height  weight  season_exp jersey        position
# 271         USA    6-3   185.0         5.0      5           Guard  \
# 362         USA   6-11   226.0         6.0     13         Forward
# 403         USA    6-7   220.0        11.0      8   Forward-Guard
# 499         USA    6-7   198.0         4.0      9   Guard-Forward
# 531         USA    6-7   190.0         3.0     10   Guard-Forward
# 686         USA    7-0   245.0        12.0     41          Center
# 708       Haiti   6-10   235.0         5.0      7  Forward-Center
# 716         USA    6-5   180.0        11.0     26   Guard-Forward
# 719         USA    6-9   248.0        10.0      7         Forward
# 747     Ukraine    7-2   250.0         9.0     25          Center
# 797      Canada    6-9   234.0         7.0     41         Forward
# 927         USA    6-0   202.0         1.0     15           Guard
# 960         USA    6-8   225.0         0.0     13         Forward
# 1026     Greece    7-1   240.0         2.0     19          Center
# 1105   Portugal    7-0   248.0         1.0     88          Center
# 1203  Lithuania    7-1   240.0         6.0     10  Forward-Center
# 1453        USA   6-11   250.0         9.0      1  Forward-Center
#
#      rosterstatus team_name draft_year draft_round draft_number
# 271        Active     Kings       2017           1            5  \
# 362      Inactive     Kings       2008           1           28
# 403      Inactive     Kings       2012           1           15
# 499        Active     Kings       2018           1           19
# 531      Inactive     Kings       2019           2           40
# 686      Inactive     Kings       2008           1           23
# 708      Inactive     Kings       2016           1           28
# 716      Inactive     Kings       2012           1           12
# 719      Inactive     Kings       2007           2           31
# 747        Active     Kings       2013           1            5
# 797        Active     Kings       2015           1           12
# 927        Active     Kings       2021           1            9
# 960        Active     Kings       2022           1            4
# 1026     Inactive     Kings       2016           1           13
# 1105       Active     Kings       2021           2           39
# 1203       Active     Kings       2016           1           11
# 1453     Inactive     Kings       2008           1           12
#
#      greatest_75_flag
# 271                 N
# 362                 N
# 403                 N
# 499                 N
# 531                 N
# 686                 N
# 708                 N
# 716                 N
# 719                 N
# 747                 N
# 797                 N
# 927                 N
# 960                 N
# 1026                N
# 1105                N
# 1203                N
# 1453                N

# %%
young_warriors = most_current_warriors.loc[most_current_warriors['draft_year'].ge('2018')].count()
young_kings = most_current_kings.loc[most_current_kings['draft_year'].ge('2018')].count()

warriors_young_players = young_warriors['display_first_last']
kings_young_players = young_kings['display_first_last']

young_players = [warriors_young_players, kings_young_players]
young_players

warriors = most_current_warriors.loc[most_current_warriors['draft_year'].ge('2018')]
kings = most_current_kings.loc[most_current_kings['draft_year'].ge('2018')]

warriors_team = warriors['team_name']
kings_team = kings['team_name']
players_team = pd.concat([warriors_team, kings_team]).unique()
players_team
# Out:
# array(['Warriors', 'Kings'], dtype=object)

# %%
# sns.boxplot(young_players)
# sns.barplot(x=['Warriors', 'Kings'], y=young_players)
sns.boxplot(x=['Warriors', 'Kings'], y=young_players)
plt.title('Players Drafted Since 2018')
plt.xlabel('Team Name')
plt.ylabel('Player Count')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
undrafted_players = nba_df.loc[(nba_df['draft_year'].eq('Undrafted')) & (nba_df['country'].ne('USA'))].count()
drafted_players = nba_df.loc[(nba_df['draft_year'].ne('Undrafted')) & (nba_df['country'].ne('USA'))].count()
drafted_undrafted = pd.concat([undrafted_players, drafted_players])
drafted_undrafted
# Out:
# person_id              45
# display_first_last     45
# birthdate              45
# school                 45
# country                45
# height                 45
# weight                 45
# season_exp             45
# jersey                 45
# position               45
# rosterstatus           45
# team_name              45
# draft_year             45
# draft_round            45
# draft_number           45
# greatest_75_flag       45
# person_id             129
# display_first_last    129
# birthdate             129
# school                129
# country               129
# height                129
# weight                129
# season_exp            129
# jersey                129
# position              129
# rosterstatus          129
# team_name             129
# draft_year            129
# draft_round           129
# draft_number          129
# greatest_75_flag      129
# dtype: int64

# %%
ax = sns.lineplot(drafted_undrafted, x=nba_df['team_name'], y=nba_df['country'])
ax.figure.set_size_inches(17, 6)
plt.title('Foreign Players (Drafted vs Undrafted)', size=17)
plt.legend(drafted_undrafted['draft_year'], loc='lower right', fontsize='13', labels=['Undrafted (45 Total)', 'Drafted (129 Total)'])
plt.xticks(rotation=90, size=11)
plt.yticks(rotation=0, size=11)
plt.xlabel('Team Name', size=15)
plt.ylabel('Country', size=15)
plt.show()
# Out:
# /tmp/ipykernel_641/3910003285.py:4: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(drafted_undrafted['draft_year'], loc='lower right', fontsize='13', labels=['Undrafted (45 Total)', 'Drafted (129 Total)'])

# %%
import pandas as pd
import numpy as np
import pyspark as ps
import pyspark.sql.functions
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nba_df = pd.read_csv('/home/blair/cognixia/AdvancedPhase/DataLake_and_DataWarehouse/nba_cleaned.csv')
nba_df
# Out:
#       person_id  display_first_last            birthdate
# 0          51.0  Mahmoud Abdul-Rauf  1969-03-09 00:00:00  \
# 1        1505.0   Tariq Abdul-Wahad  1974-11-03 00:00:00
# 2      203919.0        Jordan Adams  1994-07-08 00:00:00
# 3         912.0      Rafael Addison  1964-07-22 00:00:00
# 4      201336.0        Blake Ahearn  1984-05-27 00:00:00
# ...         ...                 ...                  ...
# 1781  1627757.0   Stephen Zimmerman  1996-09-09 00:00:00
# 1782  1627835.0         Paul Zipser  1994-02-18 00:00:00
# 1783  1627790.0          Ante Zizic  1997-01-04 00:00:00
# 1784    78648.0           Bill Zopf  1948-06-07 00:00:00
# 1785  1627826.0         Ivica Zubac  1997-03-18 00:00:00
#
#                                    school  country height  weight  season_exp
# 0                         Louisiana State      USA    6-1   162.0         9.0  \
# 1                          San Jose State   France    6-6   235.0         7.0
# 2                                    UCLA      USA    6-5   209.0         3.0
# 3                                Syracuse      USA    6-8   241.0         6.0
# 4                          Missouri State      USA    6-2   190.0         4.0
# ...                                   ...      ...    ...     ...         ...
# 1781                                 UNLV      USA    7-0   240.0         2.0
# 1782                        Bayern Munich  Germany    6-8   226.0         2.0
# 1783                                       Croatia   6-10   266.0         4.0
# 1784                             Duquesne      USA    6-1   170.0         1.0
# 1785                          Mega Basket  Croatia    7-0   240.0         6.0
#
#      jersey       position rosterstatus  team_name draft_year draft_round
# 0         1          Guard     Inactive    Nuggets       1990           1  \
# 1         9  Forward-Guard     Inactive      Kings       1997           1
# 2         3          Guard     Inactive  Grizzlies       2014           1
# 3         7        Forward     Inactive       Nets       1986           2
# 4         2          Guard     Inactive       Heat  Undrafted   Undrafted
# ...     ...            ...          ...        ...        ...         ...
# 1781     33         Center     Inactive      Magic       2016           2
# 1782     16        Forward     Inactive      Bulls       2016           2
# 1783     41         Center     Inactive  Cavaliers       2016           1
# 1784      6          Guard     Inactive      Bucks       1970           2
# 1785     40         Center       Active   Clippers       2016           2
#
#      draft_number greatest_75_flag
# 0               3                N
# 1              11                N
# 2              22                N
# 3              39                N
# 4       Undrafted                N
# ...           ...              ...
# 1781           41                N
# 1782           48                N
# 1783           23                N
# 1784           33                N
# 1785           32                N
#
# [1786 rows x 16 columns]

# %%
nba_greatest_75 = nba_df.loc[nba_df['greatest_75_flag'].eq('Y')]
# nba_greatest_75.groupby(['team_name']).describe()
nba_greatest_75_by_team = nba_greatest_75['team_name']
# nba_greatest_75_by_team = pd.DataFrame(nba_greatest_75_by_team)
nba_greatest_75_by_team.describe()
# Out:
# count         36
# unique        20
# top       Lakers
# freq           8
# Name: team_name, dtype: object

# %%
ax = sns.histplot(data=nba_greatest_75_by_team)
ax.figure.set_size_inches(12, 5)
plt.title('NBA Top 75 Team', size=17)
plt.xlabel('Team Name', size=15)
plt.ylabel('Count of Players', size=15)
plt.xticks(rotation=90, size=12)
plt.yticks(size=12)
plt.show()

# %%
warriors = nba_df[nba_df['team_name'].isin(['Warriors'])]
drafted_warriors = warriors.loc[warriors['draft_year'].ne('Undrafted')]
most_current_warriors = drafted_warriors.loc[drafted_warriors['draft_year'].ge('2005')]

drafted_warriors
most_current_warriors.head()
# Out:
#      person_id display_first_last            birthdate               school
# 68    202357.0    Nemanja Bjelica  1988-05-09 00:00:00           Fenerbahce  \
# 541   202724.0    Charles Jenkins  1989-02-28 00:00:00              Hofstra
# 548  1629660.0          Ty Jerome  1997-07-08 00:00:00             Virginia
# 698  1630228.0   Jonathan Kuminga  2002-10-06 00:00:00  NBA G League Ignite
# 779  1626172.0       Kevon Looney  1996-02-06 00:00:00                 UCLA
#
#     country height  weight  season_exp jersey       position rosterstatus
# 68   Serbia    6-9   234.0         8.0      8        Forward     Inactive  \
# 541     USA    6-3   215.0         3.0     31          Guard     Inactive
# 548     USA    6-5   195.0         3.0     10  Guard-Forward       Active
# 698     DRC    6-7   225.0         1.0     00        Forward       Active
# 779     USA    6-9   222.0         7.0      5        Forward       Active
#
#     team_name draft_year draft_round draft_number greatest_75_flag
# 68   Warriors       2010           2           35                N
# 541  Warriors       2011           2           44                N
# 548  Warriors       2019           1           24                N
# 698  Warriors       2021           1            7                N
# 779  Warriors       2015           1           30                N

# %%
kings = nba_df[nba_df['team_name'].isin(['Kings'])]
drafted_kings = kings.loc[kings['draft_year'].ne('Undrafted')]
most_current_kings = drafted_kings.loc[drafted_kings['draft_year'].ge('2005')]

most_current_kings.head()
# Out:
#      person_id display_first_last            birthdate            school
# 271  1628368.0       De'Aaron Fox  1997-12-20 00:00:00          Kentucky  \
# 362   201590.0       Donte Greene  1988-02-21 00:00:00          Syracuse
# 403   203090.0   Maurice Harkless  1993-05-11 00:00:00  St. John's, N.Y.
# 499  1628989.0      Kevin Huerter  1998-08-27 00:00:00          Maryland
# 531  1629713.0       Justin James  1997-01-24 00:00:00           Wyoming
#
#     country height  weight  season_exp jersey       position rosterstatus
# 271     USA    6-3   185.0         5.0      5          Guard       Active  \
# 362     USA   6-11   226.0         6.0     13        Forward     Inactive
# 403     USA    6-7   220.0        11.0      8  Forward-Guard     Inactive
# 499     USA    6-7   198.0         4.0      9  Guard-Forward       Active
# 531     USA    6-7   190.0         3.0     10  Guard-Forward     Inactive
#
#     team_name draft_year draft_round draft_number greatest_75_flag
# 271     Kings       2017           1            5                N
# 362     Kings       2008           1           28                N
# 403     Kings       2012           1           15                N
# 499     Kings       2018           1           19                N
# 531     Kings       2019           2           40                N

# %%
young_warriors = most_current_warriors.loc[most_current_warriors['draft_year'].ge('2018')].count()
young_kings = most_current_kings.loc[most_current_kings['draft_year'].ge('2018')].count()

warriors_young_players = young_warriors['display_first_last']
kings_young_players = young_kings['display_first_last']

young_players = [warriors_young_players, kings_young_players]
young_players

warriors = most_current_warriors.loc[most_current_warriors['draft_year'].ge('2018')]
kings = most_current_kings.loc[most_current_kings['draft_year'].ge('2018')]

warriors_team = warriors['team_name']
kings_team = kings['team_name']
players_team = pd.concat([warriors_team, kings_team]).unique()
players_team
# Out:
# array(['Warriors', 'Kings'], dtype=object)

# %%
# sns.boxplot(young_players)
# sns.barplot(x=['Warriors', 'Kings'], y=young_players)
ax = sns.barplot(x=['Warriors', 'Kings'], y=young_players, color='gold')
ax.figure.set_size_inches(10, 5)
plt.title('Players Drafted Since 2018', size=17)
plt.xlabel('Team Name', size=15)
plt.ylabel('Player Count', size=15)
plt.xticks(size=12)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
undrafted_players = nba_df.loc[(nba_df['draft_year'].eq('Undrafted')) & (nba_df['country'].ne('USA'))].count()
drafted_players = nba_df.loc[(nba_df['draft_year'].ne('Undrafted')) & (nba_df['country'].ne('USA'))].count()
drafted_undrafted = pd.concat([undrafted_players, drafted_players])
drafted_undrafted
# Out:
# person_id              45
# display_first_last     45
# birthdate              45
# school                 45
# country                45
# height                 45
# weight                 45
# season_exp             45
# jersey                 45
# position               45
# rosterstatus           45
# team_name              45
# draft_year             45
# draft_round            45
# draft_number           45
# greatest_75_flag       45
# person_id             129
# display_first_last    129
# birthdate             129
# school                129
# country               129
# height                129
# weight                129
# season_exp            129
# jersey                129
# position              129
# rosterstatus          129
# team_name             129
# draft_year            129
# draft_round           129
# draft_number          129
# greatest_75_flag      129
# dtype: int64

# %%
ax = sns.lineplot(drafted_undrafted, x=nba_df['team_name'], y=nba_df['country'])
ax.figure.set_size_inches(17, 6)
plt.title('Foreign Players (Drafted vs Undrafted)', size=17)
plt.legend(drafted_undrafted['draft_year'], loc='lower right', fontsize='13', labels=['Undrafted (45 Total)', 'Drafted (129 Total)'])
plt.xticks(rotation=90, size=11)
plt.yticks(rotation=0, size=11)
plt.xlabel('Team Name', size=15)
plt.ylabel('Country', size=15)
plt.show()
# Out:
# /tmp/ipykernel_641/3910003285.py:4: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(drafted_undrafted['draft_year'], loc='lower right', fontsize='13', labels=['Undrafted (45 Total)', 'Drafted (129 Total)'])
